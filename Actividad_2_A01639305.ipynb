# %% [markdown]
# <a href="https://colab.research.google.com/github/hudsonpanini/TC1002S/blob/main/Actividad_2_A01639305.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pwd     print working directory
#uname -r
#lsb_release -a
#lscpu
#ls -la
#cd (directory name)/
#mkdir (name)
#apt install nano
#touch hola.py
#nano hola.py
#python --version
#rm hola.py               remove

# git config --global user.email "abcd"
# git config --global user.name "aaaa"
# git clone https://token@github.com/username/repository.git

# git add hola.py
# git commit "un script de python"
# git push

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 1. Crea una celda de código con el siguiente código e imprime el dataframe.

# %%
#dataframe ficticio de ventas de frutas
df = pd.DataFrame({'Product': ['Carrots', 'Broccoli', 'Banana', 'Banana',
 'Beans', 'Orange', 'Broccoli', 'Banana'],
 'Category': ['Vegetable', 'Vegetable', 'Fruit', 'Fruit',
 'Vegetable', 'Fruit', 'Vegetable', 'Fruit'],
 'Quantity': [8, 5, 3, 4, 5, 9, 11, 8],
 'Amount': [270, 239, 617, 384, 626, 610, 62, 90]})
print(df)
# Out:
#     Product   Category  Quantity  Amount
# 0   Carrots  Vegetable         8     270
# 1  Broccoli  Vegetable         5     239
# 2    Banana      Fruit         3     617
# 3    Banana      Fruit         4     384
# 4     Beans  Vegetable         5     626
# 5    Orange      Fruit         9     610
# 6  Broccoli  Vegetable        11      62
# 7    Banana      Fruit         8      90

# %% [markdown]
# 2. Selecciona e imprime las columnas de Product y Quantity.

# %%
df[['Product','Quantity']]
# Out:
#     Product  Quantity
# 0   Carrots         8
# 1  Broccoli         5
# 2    Banana         3
# 3    Banana         4
# 4     Beans         5
# 5    Orange         9
# 6  Broccoli        11
# 7    Banana         8

# %% [markdown]
# 3. Selecciona e imprime los renglones con índices 4 y 6.

# %%
df.loc[[4,6]]
# Out:
#     Product   Category  Quantity  Amount
# 4     Beans  Vegetable         5     626
# 6  Broccoli  Vegetable        11      62

# %% [markdown]
# 4. Usando el método groupby, agrupa usando la columna Product y muestra la suma de la columna Quantity.

# %%
por_product = df.groupby("Product")
por_product["Quantity"].sum()
# Out:
# Product
# Banana      15
# Beans        5
# Broccoli    16
# Carrots      8
# Orange       9
# Name: Quantity, dtype: int64

# %% [markdown]
# 5. Usando el método groupby, agrupa usando la columna Category y muestra la suma de la columna Amount.

# %%
por_product = df.groupby("Category")
por_product["Amount"].sum()
# Out:
# Category
# Fruit        1701
# Vegetable    1197
# Name: Amount, dtype: int64
